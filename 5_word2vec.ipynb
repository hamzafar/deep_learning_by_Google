# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5238, 3081, 12, 6, 195, 2, 3136, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'originated', 'a', 'as', 'originated', 'term', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.030327
# Nearest to known: henotheism, likeness, hides, spectrometer, chili, collaborating, grozny, megiddo,
# Nearest to only: mobutu, considerations, stripes, liberally, supernaturally, coupland, cpm, azathoth,
# Nearest to people: koine, infected, hearse, pigot, russcol, sault, surrender, existentialists,
# Nearest to there: fills, rcc, trs, buds, zacharias, documentary, roc, thracian,
# Nearest to th: cardiovascular, alluvial, jref, lamborghini, ligurian, dates, secluded, crystallized,
# Nearest to over: issuance, roman, innocence, grosso, marcel, nanotube, aiming, hydrocodone,
# Nearest to history: curd, councilors, maoism, mafioso, waka, luna, silvio, linda,
# Nearest to war: trumped, morals, incremental, camilla, hulled, imbalances, gens, mp,
# Nearest to he: fujitsu, jade, marangella, tristar, autocratic, gneiss, simultaneous, tt,
# Nearest to years: tetris, enjoyed, tuttle, prevails, laguna, hindus, burrows, secularization,
# Nearest to their: vdp, transfusions, morpheme, fantasia, contrasted, piter, muggles, testimony,
# Nearest to two: fowler, comoros, leningrad, rolling, sami, rubber, waged, recovery,
# Nearest to a: obscure, copa, psalm, mnt, duncan, deities, weeks, furthermore,
# Nearest to is: verge, metastability, african, skier, djinn, agarose, security, suarez,
# Nearest to three: torgau, addons, evolutionarily, clavichord, hesitate, gestures, cayuga, rail,
# Nearest to has: missa, clause, vertices, broughton, speeding, spinach, tod, individuals,
# Average loss at step 2000: 4.367180
# Average loss at step 4000: 3.861619
# Average loss at step 6000: 3.792527
# Average loss at step 8000: 3.688966
# Average loss at step 10000: 3.616836
# Nearest to known: hides, pubic, such, azt, metre, luz, spectrometer, shall,
# Nearest to only: azathoth, made, considerations, prizes, mobutu, pedals, bar, scaffold,
# Nearest to people: lange, placidia, referred, jiva, davidians, badly, dudayev, traditions,
# Nearest to there: it, they, commonly, he, still, rcc, trs, intelligent,
# Nearest to th: cardiovascular, hoof, jref, melton, cleese, telegrams, alluvial, kawasaki,
# Nearest to over: marcel, on, green, roman, innocence, retina, issuance, amar,
# Nearest to history: councilors, linda, waka, curd, sickle, norbert, silvio, luna,
# Nearest to war: trumped, gens, incremental, morals, imbalances, stockpiling, incorporated, digby,
# Nearest to he: it, they, she, who, simultaneous, also, there, coroner,
# Nearest to years: burrows, somaliland, secularization, tetris, cde, enjoyed, bocce, batsman,
# Nearest to their: its, his, the, floor, dsl, tandy, mataram, pinball,
# Nearest to two: five, four, three, six, eight, one, seven, nine,
# Nearest to a: the, duncan, polluting, pampas, canarian, this, drosophila, intertwined,
# Nearest to is: was, are, has, be, eisner, excrement, hospitality, affirms,
# Nearest to three: four, six, five, eight, seven, two, nine, zero,
# Nearest to has: had, is, was, have, hut, transactional, sargent, unstable,
# Average loss at step 12000: 3.602888
# Average loss at step 14000: 3.575841
# Average loss at step 16000: 3.406980
# Average loss at step 18000: 3.458152
# Average loss at step 20000: 3.537839
# Nearest to known: hides, such, azt, pubic, used, possible, hammerstein, wankel,
# Nearest to only: always, it, pedals, jimi, chechen, azathoth, bar, last,
# Nearest to people: able, jiva, referred, appreciable, spurt, you, badly, encroaching,
# Nearest to there: it, they, he, which, still, commonly, macrostate, handshake,
# Nearest to th: cardiovascular, jref, melton, hoof, one, telegrams, secluded, obtainable,
# Nearest to over: clarinetists, retina, marcel, roman, on, innocence, audience, amar,
# Nearest to history: list, curd, luna, norbert, councilors, abomination, features, cultural,
# Nearest to war: trumped, gens, digby, morals, stockpiling, imbalances, incremental, cops,
# Nearest to he: it, she, they, who, there, which, undercarriage, this,
# Nearest to years: somaliland, burrows, secularization, days, bashing, tetris, bocce, cde,
# Nearest to their: its, his, the, her, floor, both, systematized, authoritarianism,
# Nearest to two: three, five, four, six, eight, seven, zero, one,
# Nearest to a: this, polluting, the, pampas, drosophila, ecstatic, installments, any,
# Nearest to is: was, are, has, be, were, but, bundy, although,
# Nearest to three: five, four, seven, six, eight, two, zero, nine,
# Nearest to has: had, have, was, is, hut, wracked, kifl, pennies,
# Average loss at step 22000: 3.502299
# Average loss at step 24000: 3.490800
# Average loss at step 26000: 3.480809
# Average loss at step 28000: 3.483149
# Average loss at step 30000: 3.501556
# Nearest to known: used, hides, possible, such, azt, well, lemur, far,
# Nearest to only: always, pedals, quatrain, last, either, it, fairtrade, teenager,
# Nearest to people: things, encroaching, instruments, hampering, offside, landes, appreciable, bread,
# Nearest to there: they, it, he, still, usually, now, she, widely,
# Nearest to th: cardiovascular, melton, eight, nd, hoof, satirize, jref, cd,
# Nearest to over: clarinetists, wta, transformers, lizard, lipoproteins, roman, isomorphism, gif,
# Nearest to history: list, luna, cambridge, norbert, atomic, chemist, councilors, features,
# Nearest to war: trumped, gens, morals, sepia, imbalances, digby, veterans, unspoiled,
# Nearest to he: she, it, they, who, there, but, meagre, however,
# Nearest to years: somaliland, days, times, months, bocce, bashing, burrows, secularization,
# Nearest to their: its, his, the, her, our, these, floor, your,
# Nearest to two: four, three, one, five, seven, six, eight, zero,
# Nearest to a: ecstatic, any, confederal, this, drill, no, ratu, the,
# Nearest to is: was, has, are, became, excrement, although, be, butcher,
# Nearest to three: four, seven, five, two, six, eight, nine, zero,
# Nearest to has: had, have, is, was, transactional, expanding, hut, willy,
# Average loss at step 32000: 3.505169
# Average loss at step 34000: 3.492267
# Average loss at step 36000: 3.453765
# Average loss at step 38000: 3.300425
# Average loss at step 40000: 3.432860
# Nearest to known: used, hides, such, possible, classified, described, brahmagupta, azt,
# Nearest to only: always, last, paideia, spacious, chechen, better, pedals, either,
# Nearest to people: things, others, someone, those, recruiting, continuously, offside, men,
# Nearest to there: they, it, he, usually, she, often, now, which,
# Nearest to th: nd, seven, eight, cardiovascular, hoof, melton, cd, st,
# Nearest to over: clarinetists, marcel, isomorphism, fireballs, dup, unguarded, slur, wta,
# Nearest to history: list, curd, norbert, historical, institution, motivate, rs, brief,
# Nearest to war: trumped, gens, raisin, unspoiled, optimal, penitentiary, camilla, stockpiling,
# Nearest to he: she, it, they, who, there, i, soon, however,
# Nearest to years: days, months, somaliland, times, burrows, blackfoot, bocce, bashing,
# Nearest to their: its, his, her, the, our, floor, your, these,
# Nearest to two: three, four, five, six, seven, one, eight, zero,
# Nearest to a: the, any, derg, no, another, ribera, uni, canarian,
# Nearest to is: was, are, be, has, became, ces, if, shows,
# Nearest to three: four, five, two, seven, six, eight, nine, zero,
# Nearest to has: had, have, was, is, transactional, recede, hut, nes,
# Average loss at step 42000: 3.434947
# Average loss at step 44000: 3.453542
# Average loss at step 46000: 3.448983
# Average loss at step 48000: 3.355776
# Average loss at step 50000: 3.383904
# Nearest to known: used, possible, such, hides, described, brahmagupta, classified, monoids,
# Nearest to only: either, always, last, goodwill, never, tzu, first, moi,
# Nearest to people: things, men, others, children, someone, ducal, jews, hampering,
# Nearest to there: they, it, he, she, often, still, usually, appliances,
# Nearest to th: eight, six, nd, one, seven, satirize, st, mars,
# Nearest to over: clarinetists, dup, on, isomorphism, wta, soften, marcel, fleischmann,
# Nearest to history: list, norbert, institution, brief, directors, curd, councilors, couples,
# Nearest to war: trumped, gens, raisin, digby, stockpiling, optimal, purest, cerevisiae,
# Nearest to he: she, it, they, who, there, eventually, animations, homeschooling,
# Nearest to years: days, months, times, somaliland, blackfoot, vertebra, bocce, year,
# Nearest to their: its, his, our, her, the, both, your, these,
# Nearest to two: three, four, six, one, five, seven, eight, zero,
# Nearest to a: any, the, no, another, ribera, immigrated, toothpaste, derg,
# Nearest to is: was, are, has, although, be, while, were, became,
# Nearest to three: six, four, seven, five, two, eight, nine, zero,
# Nearest to has: had, have, was, is, since, anticipating, seems, unstable,
# Average loss at step 52000: 3.438916
# Average loss at step 54000: 3.424497
# Average loss at step 56000: 3.438096
# Average loss at step 58000: 3.401058
# Average loss at step 60000: 3.396759
# Nearest to known: used, such, possible, hides, described, classified, regarded, brahmagupta,
# Nearest to only: always, either, last, first, tzu, moi, never, usually,
# Nearest to people: things, others, men, those, children, someone, jews, individuals,
# Nearest to there: they, it, now, often, he, usually, she, this,
# Nearest to th: eight, five, nd, st, four, airbase, satirize, pinyin,
# Nearest to over: into, dup, around, clarinetists, ris, feodor, pel, about,
# Nearest to history: list, demographics, directors, brief, hypothesized, usage, historical, interests,
# Nearest to war: trumped, gens, raisin, veterans, penitentiary, champions, energetic, primo,
# Nearest to he: she, it, they, there, we, who, eventually, soon,
# Nearest to years: days, months, times, year, blackfoot, centuries, vertebra, somaliland,
# Nearest to their: its, his, her, our, the, your, these, enclose,
# Nearest to two: three, four, five, six, one, eight, seven, zero,
# Nearest to a: another, the, any, every, ideologically, toothpaste, polluting, bytecode,
# Nearest to is: was, are, has, be, seems, although, remains, bilirubin,
# Nearest to three: five, four, six, eight, seven, two, nine, zero,
# Nearest to has: had, have, is, was, having, anticipating, photo, nebraska,
# Average loss at step 62000: 3.246457
# Average loss at step 64000: 3.256307
# Average loss at step 66000: 3.402358
# Average loss at step 68000: 3.393450
# Average loss at step 70000: 3.361701
# Nearest to known: used, such, described, regarded, hides, possible, monoids, brahmagupta,
# Nearest to only: last, either, never, always, better, tzu, lead, moi,
# Nearest to people: men, things, others, children, hampering, someone, those, jews,
# Nearest to there: they, it, now, often, usually, he, still, we,
# Nearest to th: bc, st, airbase, cd, satirize, nd, six, kawasaki,
# Nearest to over: around, coincident, dup, tanakh, idol, pentium, ecclesia, into,
# Nearest to history: list, demographics, directors, hypothesized, discussion, brief, curd, historical,
# Nearest to war: trumped, veterans, penitentiary, gens, preceding, champions, quelled, primo,
# Nearest to he: she, it, they, there, who, eventually, we, soon,
# Nearest to years: days, months, year, times, centuries, decades, vertebra, blackfoot,
# Nearest to their: its, his, her, our, the, your, these, my,
# Nearest to two: three, six, four, seven, five, one, eight, zero,
# Nearest to a: the, another, any, pampas, dorms, affinities, obscure, ideologically,
# Nearest to is: was, has, are, be, excrement, although, seems, does,
# Nearest to three: four, six, two, five, seven, eight, nine, zero,
# Nearest to has: had, have, was, is, since, deterred, having, anticipating,
# Average loss at step 72000: 3.371416
# Average loss at step 74000: 3.349129
# Average loss at step 76000: 3.324183
# Average loss at step 78000: 3.352822
# Average loss at step 80000: 3.379785
# Nearest to known: used, described, regarded, such, classified, possible, opposed, hides,
# Nearest to only: last, either, always, better, until, never, spacious, actually,
# Nearest to people: men, children, things, others, someone, hampering, players, those,
# Nearest to there: they, it, he, now, usually, often, we, she,
# Nearest to th: bc, st, nd, seven, six, five, airbase, satirize,
# Nearest to over: around, isomorphism, coincident, between, within, about, masuria, pel,
# Nearest to history: list, historical, brief, luna, hypothesized, nzenberg, plot, demographics,
# Nearest to war: veterans, gens, quelled, preceding, trumped, gadgets, post, wars,
# Nearest to he: she, it, they, there, eventually, who, we, subsequently,
# Nearest to years: days, months, times, year, centuries, decades, blackfoot, hours,
# Nearest to their: its, her, his, our, your, the, my, several,
# Nearest to two: three, four, six, five, seven, one, eight, zero,
# Nearest to a: another, the, every, bytecode, any, dorms, snl, confederal,
# Nearest to is: was, has, are, became, does, although, be, bougainville,
# Nearest to three: four, six, seven, five, two, eight, nine, zero,
# Nearest to has: had, have, is, was, deterred, since, anticipating, having,
# Average loss at step 82000: 3.406676
# Average loss at step 84000: 3.414897
# Average loss at step 86000: 3.390274
# Average loss at step 88000: 3.350960
# Average loss at step 90000: 3.365341
# Nearest to known: used, such, regarded, described, possible, called, opposed, classified,
# Nearest to only: either, last, always, never, actually, goodwill, moi, camps,
# Nearest to people: men, children, things, players, someone, women, others, hampering,
# Nearest to there: they, it, he, she, now, still, often, generally,
# Nearest to th: bc, one, seven, eight, nd, st, ce, rd,
# Nearest to over: around, within, dup, masuria, coincident, between, pel, against,
# Nearest to history: list, historical, brief, luna, discussion, demographics, hypothesized, usage,
# Nearest to war: veterans, optimal, preceding, gadgets, wars, mestizos, thorn, trumped,
# Nearest to he: she, they, it, there, who, eventually, but, subsequently,
# Nearest to years: days, months, decades, year, centuries, hours, times, minutes,
# Nearest to their: its, his, her, our, your, my, whose, the,
# Nearest to two: three, four, five, seven, eight, six, one, nine,
# Nearest to a: the, another, any, midwife, kajang, every, slumberland, derg,
# Nearest to is: was, has, are, although, contains, does, while, requires,
# Nearest to three: four, two, five, seven, eight, six, nine, zero,
# Nearest to has: had, have, is, was, having, since, anticipating, transactional,
# Average loss at step 92000: 3.400653
# Average loss at step 94000: 3.258960
# Average loss at step 96000: 3.358917
# Average loss at step 98000: 3.245451
# Average loss at step 100000: 3.354183
# Nearest to known: used, such, possible, regarded, classified, opposed, described, monoids,
# Nearest to only: either, never, goodwill, last, daimler, no, always, moi,
# Nearest to people: children, men, players, things, someone, others, women, those,
# Nearest to there: they, he, it, now, often, generally, we, macrostate,
# Nearest to th: bc, nd, second, rd, canola, satirize, third, one,
# Nearest to over: around, dup, coincident, chewing, within, between, isomorphism, pentium,
# Nearest to history: list, historical, exclusion, discussion, plot, brief, demographics, interests,
# Nearest to war: battle, veterans, wars, cerevisiae, preceding, mestizos, fontana, raisin,
# Nearest to he: she, it, they, there, who, we, subsequently, eventually,
# Nearest to years: days, months, year, decades, hours, centuries, seconds, times,
# Nearest to their: its, his, our, her, your, my, the, whose,
# Nearest to two: three, four, six, five, eight, seven, one, nine,
# Nearest to a: another, any, the, ideologically, ecstatic, midwife, every, slumberland,
# Nearest to is: was, has, became, seems, be, are, although, remains,
# Nearest to three: four, five, six, two, seven, eight, nine, zero,
# Nearest to has: had, have, is, was, since, anticipating, having, transactional,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
