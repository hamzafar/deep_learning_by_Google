# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5237, 3082, 12, 6, 195, 2, 3136, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'originated', 'anarchism', 'originated', 'term', 'as', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.329123
# Nearest to as: sussman, menezes, wanted, resuscitation, glossaries, pieces, forbes, asexual,
# Nearest to has: dandelion, superficially, halifax, malnutrition, telegraph, undamaged, dumpster, licht,
# Nearest to most: businessweek, deliverance, buildings, newsletters, museo, applicative, doses, nye,
# Nearest to his: cinemas, cerevisiae, ludi, harman, knuckle, steadily, pca, analytical,
# Nearest to can: experimented, thracians, saturdays, volatile, lautering, jagiello, syntax, hydrology,
# Nearest to seven: yevgeny, tocharians, absorbs, expansion, commedia, thirteen, zariski, nod,
# Nearest to two: ner, mattered, ample, aruban, draft, myositis, yorkers, parentheses,
# Nearest to american: pagans, overlords, javan, ethnomusicology, australia, debt, atheroma, voids,
# Nearest to than: cared, levitation, dum, releasing, moshe, overcome, slick, barfield,
# Nearest to its: monotremes, gels, iru, commonly, fiesole, really, osce, edmond,
# Nearest to which: kms, lith, monoid, salaam, principe, heim, ala, directives,
# Nearest to four: hodgkin, upholds, swamps, xiv, schizophrenic, tli, doom, vail,
# Nearest to years: halter, popped, etch, levantine, elektra, misconception, convenes, drava,
# Nearest to their: inaccurately, abortive, throes, keralites, engaged, folks, tranquility, kinetics,
# Nearest to history: encephalitis, fangio, eurocents, commandment, barca, overlooking, kangaroos, warr,
# Nearest to about: puranas, lata, stabilize, timely, contrastive, viaduct, tze, theodora,
# Average loss at step 2000: 4.361365
# Average loss at step 4000: 3.863050
# Average loss at step 6000: 3.787347
# Average loss at step 8000: 3.691111
# Average loss at step 10000: 3.613278
# Nearest to as: ithilien, suzuki, muriel, grassy, oxide, dreamlike, fingal, bicycles,
# Nearest to has: had, was, have, is, dandelion, coordinating, grassy, clintons,
# Nearest to most: museo, businessweek, courtly, worst, deliverance, myrddin, powerpoint, sensuous,
# Nearest to his: their, the, its, s, analytical, orators, griffith, pad,
# Nearest to can: would, may, could, will, must, lalr, legal, deathbed,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to two: three, four, five, seven, one, six, eight, zero,
# Nearest to american: overlords, abhidhamma, oriented, speaker, voids, cygwin, foreword, fascist,
# Nearest to than: levitation, releasing, mauryan, or, burying, awoke, barfield, slick,
# Nearest to its: his, their, the, our, neurologic, behaviour, gels, illusory,
# Nearest to which: that, it, this, challenges, also, buccaneer, and, liability,
# Nearest to four: six, three, five, eight, seven, two, zero, nine,
# Nearest to years: pompey, misconception, elektra, racetrack, levantine, drava, bunyip, przewodnicz,
# Nearest to their: his, the, its, abortive, inaccurately, analytical, her, engaged,
# Nearest to history: eurocents, encephalitis, shortest, kangaroos, commandment, sense, particulars, mussels,
# Nearest to about: lata, timely, puranas, wpa, adelaide, lyotropic, stabilize, tze,
# Average loss at step 12000: 3.603983
# Average loss at step 14000: 3.569901
# Average loss at step 16000: 3.407898
# Average loss at step 18000: 3.461721
# Average loss at step 20000: 3.542475
# Nearest to as: grassy, navarrese, jair, muriel, boogie, regular, bicycles, coils,
# Nearest to has: had, have, was, is, griff, having, coordinating, capacitance,
# Nearest to most: sensuous, more, many, museo, courtly, powerpoint, buildings, businessweek,
# Nearest to his: their, her, its, the, royalty, neighbourhoods, our, grains,
# Nearest to can: may, would, will, could, must, deathbed, lalr, to,
# Nearest to seven: eight, six, nine, five, four, three, two, zero,
# Nearest to two: three, four, five, six, seven, eight, one, zero,
# Nearest to american: overlords, and, german, kernighan, australian, french, expo, ethan,
# Nearest to than: or, burying, levitation, mauryan, releasing, scone, slick, overcome,
# Nearest to its: their, the, his, our, her, riichi, nepal, a,
# Nearest to which: this, that, also, who, it, and, but, what,
# Nearest to four: five, three, six, eight, seven, two, nine, zero,
# Nearest to years: pompey, days, racetrack, robe, bunyip, przewodnicz, aedile, misconception,
# Nearest to their: its, his, the, her, some, these, wmo, abortive,
# Nearest to history: sense, structure, capitulation, kangaroos, commandment, mussels, shortest, encephalitis,
# Nearest to about: lata, timely, puranas, orkney, tze, stabilize, guard, augustinian,
# Average loss at step 22000: 3.500468
# Average loss at step 24000: 3.492270
# Average loss at step 26000: 3.480637
# Average loss at step 28000: 3.477390
# Average loss at step 30000: 3.503473
# Nearest to as: by, navarrese, shimazu, fingal, oxide, percy, coils, quaint,
# Nearest to has: had, have, is, was, having, griff, gated, coordinating,
# Nearest to most: many, more, some, sensuous, powerpoint, courtly, deliverance, dumpster,
# Nearest to his: their, her, its, the, s, litani, our, pondicherry,
# Nearest to can: may, would, will, could, must, might, cannot, should,
# Nearest to seven: eight, four, five, nine, six, three, two, zero,
# Nearest to two: three, four, seven, five, one, six, eight, zero,
# Nearest to american: british, english, australian, german, indian, kernighan, overlords, fascist,
# Nearest to than: or, burying, levitation, mauryan, slick, releasing, overcome, scone,
# Nearest to its: their, his, the, our, riichi, her, wmo, rowdy,
# Nearest to which: this, that, it, also, what, these, who, parisian,
# Nearest to four: five, seven, six, three, eight, two, nine, zero,
# Nearest to years: days, year, forage, racetrack, bunyip, ways, robe, months,
# Nearest to their: its, his, her, the, our, these, some, wmo,
# Nearest to history: commandment, sense, capitulation, mussels, structure, devries, kangaroos, eurocents,
# Nearest to about: lata, orkney, above, guard, nerd, beyond, latter, annual,
# Average loss at step 32000: 3.502081
# Average loss at step 34000: 3.495579
# Average loss at step 36000: 3.449504
# Average loss at step 38000: 3.302748
# Average loss at step 40000: 3.429419
# Nearest to as: stockpiling, inadequate, jacinto, regular, navarrese, oxide, by, eretz,
# Nearest to has: had, have, was, griff, having, is, gated, jeb,
# Nearest to most: more, many, some, sensuous, museo, powerpoint, dumpster, courtly,
# Nearest to his: their, her, its, the, s, my, litani, our,
# Nearest to can: may, would, will, could, must, cannot, should, might,
# Nearest to seven: four, nine, eight, six, five, three, zero, two,
# Nearest to two: three, four, six, five, seven, one, eight, zero,
# Nearest to american: british, english, australian, german, french, irish, clutching, overlords,
# Nearest to than: or, burying, foreground, levitation, spinners, guant, mauryan, no,
# Nearest to its: their, his, our, the, her, awakened, wmo, surpasses,
# Nearest to which: that, this, also, it, who, there, what, often,
# Nearest to four: six, seven, three, eight, five, two, nine, one,
# Nearest to years: days, year, months, racetrack, ways, robe, forage, tius,
# Nearest to their: its, his, her, the, some, our, these, any,
# Nearest to history: kangaroos, appellations, origin, capitulation, geography, eggplant, mw, roused,
# Nearest to about: guard, firewall, cognomen, lyotropic, nerd, orkney, million, linguistically,
# Average loss at step 42000: 3.434564
# Average loss at step 44000: 3.454321
# Average loss at step 46000: 3.452901
# Average loss at step 48000: 3.351321
# Average loss at step 50000: 3.384515
# Nearest to as: navarrese, oxide, clary, muriel, uganda, enol, jacinto, too,
# Nearest to has: had, have, is, was, having, gated, since, griff,
# Nearest to most: more, many, some, among, kul, powerpoint, sensuous, biplanes,
# Nearest to his: their, her, its, my, the, our, him, whose,
# Nearest to can: could, would, may, will, must, might, should, cannot,
# Nearest to seven: six, eight, four, nine, five, three, zero, one,
# Nearest to two: three, one, six, four, five, seven, eight, zero,
# Nearest to american: english, australian, indian, irish, british, french, austrian, pop,
# Nearest to than: or, burying, foreground, yellowstone, levitation, overcome, and, spinners,
# Nearest to its: their, his, our, the, her, remarry, horrible, laurel,
# Nearest to which: this, that, also, who, what, these, it, usually,
# Nearest to four: six, three, five, seven, eight, nine, zero, two,
# Nearest to years: days, months, year, racetrack, tius, ims, times, ways,
# Nearest to their: its, his, her, the, our, pondicherry, any, these,
# Nearest to history: appellations, list, origin, mussels, kangaroos, university, capitulation, voluminous,
# Nearest to about: firewall, guard, nerd, linguistically, latter, dvorak, cognomen, orkney,
# Average loss at step 52000: 3.438471
# Average loss at step 54000: 3.429877
# Average loss at step 56000: 3.442545
# Average loss at step 58000: 3.398866
# Average loss at step 60000: 3.390586
# Nearest to as: cesium, quell, thermometer, enol, clary, sol, navarrese, muriel,
# Nearest to has: had, have, is, was, having, provides, griff, gated,
# Nearest to most: many, more, some, supplier, all, among, both, frigate,
# Nearest to his: their, her, its, my, our, the, autograph, him,
# Nearest to can: may, could, would, must, will, might, should, cannot,
# Nearest to seven: eight, four, nine, six, five, zero, three, one,
# Nearest to two: three, four, five, six, one, seven, eight, zero,
# Nearest to american: english, australian, british, irish, indian, german, french, international,
# Nearest to than: or, and, but, burying, foreground, much, yellowstone, scone,
# Nearest to its: their, his, our, the, her, your, surpasses, rowdy,
# Nearest to which: that, this, what, who, typically, it, located, also,
# Nearest to four: five, six, eight, three, seven, nine, zero, two,
# Nearest to years: days, months, year, decades, weeks, bourbon, tius, ways,
# Nearest to their: its, his, her, the, our, these, abortive, whose,
# Nearest to history: origin, tsvetaeva, list, economy, comic, spoofed, roused, politics,
# Nearest to about: firewall, nerd, lata, carolingian, million, guard, urging, over,
# Average loss at step 62000: 3.240369
# Average loss at step 64000: 3.254286
# Average loss at step 66000: 3.403111
# Average loss at step 68000: 3.396941
# Average loss at step 70000: 3.362638
# Nearest to as: when, coils, clary, gorman, quell, provincias, simulating, colliding,
# Nearest to has: had, have, is, was, having, since, requires, gated,
# Nearest to most: more, many, some, particularly, all, less, museo, use,
# Nearest to his: her, their, its, my, our, whose, absurdist, the,
# Nearest to can: may, could, would, will, must, might, should, cannot,
# Nearest to seven: eight, six, four, five, nine, three, zero, two,
# Nearest to two: three, four, six, five, one, seven, eight, zero,
# Nearest to american: english, australian, british, irish, indian, french, german, asian,
# Nearest to than: burying, but, foreground, or, much, and, spinners, algol,
# Nearest to its: their, his, the, her, our, some, your, rowdy,
# Nearest to which: that, this, but, also, usually, however, what, actually,
# Nearest to four: six, five, three, seven, eight, two, zero, nine,
# Nearest to years: days, months, year, decades, percent, centuries, ways, weeks,
# Nearest to their: its, his, her, the, our, some, my, your,
# Nearest to history: list, origin, comic, discussion, tsvetaeva, spoofed, form, bas,
# Nearest to about: firewall, nerd, neurological, over, dvorak, carolingian, domino, urging,
# Average loss at step 72000: 3.369913
# Average loss at step 74000: 3.347729
# Average loss at step 76000: 3.318599
# Average loss at step 78000: 3.349320
# Average loss at step 80000: 3.375594
# Nearest to as: oxide, cesium, truman, nl, bunnies, ingalls, provincias, when,
# Nearest to has: had, have, is, was, having, since, requires, gated,
# Nearest to most: many, more, some, particularly, among, all, hostilities, nerves,
# Nearest to his: her, their, its, our, my, your, the, whose,
# Nearest to can: may, could, will, would, must, cannot, might, should,
# Nearest to seven: six, four, five, eight, nine, three, zero, two,
# Nearest to two: three, four, six, five, seven, one, eight, zero,
# Nearest to american: australian, english, british, german, french, indian, irish, canadian,
# Nearest to than: or, burying, much, but, while, spinners, diputados, algol,
# Nearest to its: their, his, our, her, the, your, remarry, rowdy,
# Nearest to which: that, this, usually, also, what, both, where, often,
# Nearest to four: five, six, seven, three, eight, two, nine, zero,
# Nearest to years: days, months, decades, year, weeks, centuries, minutes, ways,
# Nearest to their: its, his, her, our, your, the, my, pondicherry,
# Nearest to history: list, origin, tsvetaeva, comic, divergent, amusingly, panthera, because,
# Nearest to about: firewall, over, akimbo, dvorak, leninist, beast, carolingian, neurological,
# Average loss at step 82000: 3.408866
# Average loss at step 84000: 3.410841
# Average loss at step 86000: 3.392513
# Average loss at step 88000: 3.350063
# Average loss at step 90000: 3.362609
# Nearest to as: navarrese, cesium, ingalls, quell, clary, ningen, gorman, enol,
# Nearest to has: had, have, is, was, requires, having, since, provides,
# Nearest to most: many, some, more, particularly, all, various, among, several,
# Nearest to his: her, their, its, our, my, your, the, whose,
# Nearest to can: may, could, will, would, must, might, cannot, should,
# Nearest to seven: eight, four, six, five, nine, three, zero, two,
# Nearest to two: three, four, five, six, seven, one, eight, zero,
# Nearest to american: british, australian, french, english, german, indian, african, canadian,
# Nearest to than: burying, diputados, or, spinners, efficient, foreground, stable, much,
# Nearest to its: their, his, her, our, the, whose, iru, inordinate,
# Nearest to which: that, also, this, usually, both, what, who, often,
# Nearest to four: seven, six, five, three, eight, nine, two, zero,
# Nearest to years: days, months, decades, year, weeks, minutes, centuries, ways,
# Nearest to their: its, his, her, our, your, the, my, whose,
# Nearest to history: list, origin, amusingly, tsvetaeva, geography, pennies, coworkers, triumph,
# Nearest to about: firewall, on, neurological, carolingian, nerd, dvorak, leninist, akimbo,
# Average loss at step 92000: 3.399804
# Average loss at step 94000: 3.253307
# Average loss at step 96000: 3.358829
# Average loss at step 98000: 3.240275
# Average loss at step 100000: 3.361548
# Nearest to as: bunnies, ningen, navarrese, cesium, quell, provincias, howto, when,
# Nearest to has: had, have, is, was, since, having, requires, griff,
# Nearest to most: more, less, many, among, particularly, especially, some, several,
# Nearest to his: her, their, my, our, your, its, the, whose,
# Nearest to can: could, may, will, must, would, might, cannot, should,
# Nearest to seven: eight, six, four, five, nine, three, zero, two,
# Nearest to two: three, five, four, six, eight, one, seven, zero,
# Nearest to american: british, australian, canadian, irish, english, french, benchmark, indian,
# Nearest to than: or, burying, much, considerably, efficient, spinners, while, microcontroller,
# Nearest to its: their, his, our, the, her, riichi, laurel, iru,
# Nearest to which: that, this, usually, what, these, but, actually, typically,
# Nearest to four: six, seven, five, eight, three, nine, two, zero,
# Nearest to years: days, months, decades, year, weeks, minutes, centuries, percent,
# Nearest to their: its, his, her, our, your, the, these, my,
# Nearest to history: list, amusingly, origin, geography, panthera, tsvetaeva, botticelli, coworkers,
# Nearest to about: on, rufinus, schiff, akimbo, ditto, nerd, polycarbonate, neurological,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# The model proposed is such simple in getting contexts so we can just swap labels and inputs to get CBOW analogy

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        # WOW SUCH CBOW
        batch_labels, batch_data = generate_batch(batch_size, num_skips, skip_window)
        batch_data = batch_data.reshape((batch_size,))
        batch_labels = batch_labels.reshape((batch_size, 1))
        
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From <ipython-input-10-4aa55ae93a88>:4: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 8.086739
# Nearest to as: bpm, masterpieces, accommodated, sacred, trance, lett, progeny, kanaris,
# Nearest to has: feces, adenauer, jongg, satsuma, rabbis, fukuoka, selkirk, heretical,
# Nearest to most: cypriot, gogo, dessau, ecoregions, scandinavian, exceed, hierarchically, logan,
# Nearest to his: petroleum, trna, alone, near, wires, manhood, stomachs, sayfawa,
# Nearest to can: seriously, orb, apeiron, flagg, aarseth, aldermen, fifth, geralt,
# Nearest to seven: shockwave, payload, monarch, tear, deliriants, stripped, impurities, oppressed,
# Nearest to two: darshan, disregard, misdiagnosed, fancher, discussions, craps, nostalgic, funicular,
# Nearest to american: neuroscience, composed, immune, gfdl, coached, liquidation, karaoke, rupture,
# Nearest to than: rationalization, barbagia, rothbard, flippers, midday, nitrogenous, allegiances, zamboanga,
# Nearest to its: none, hypotheses, bandage, turnover, seller, susima, wielded, toomer,
# Nearest to which: detainee, saipan, ju, male, accountability, soga, stables, staffed,
# Nearest to four: purposes, individually, atlanteans, expositions, vietnam, eviction, insist, patiently,
# Nearest to years: cashier, derision, cliath, backlit, zuse, browns, unknowns, guin,
# Nearest to their: chakra, wic, existed, businesspeople, gdynia, tricked, address, eschewing,
# Nearest to history: jaynes, gate, evaluate, noether, latvians, rigorous, hora, bowie,
# Nearest to about: mcclintock, rowan, wace, crop, terrier, websites, cornwall, monist,
# Average loss at step 2000: 4.384208
# Average loss at step 4000: 3.872767
# Average loss at step 6000: 3.799168
# Average loss at step 8000: 3.756205
# Average loss at step 10000: 3.616110
# Nearest to as: masterpieces, accommodated, sacred, allergies, wahid, particular, die, trance,
# Nearest to has: had, have, is, was, by, tripod, are, important,
# Nearest to most: speculate, trapezohedron, scandinavian, intercepting, gogo, finds, shimizu, production,
# Nearest to his: their, its, the, s, trna, wires, her, stomachs,
# Nearest to can: must, would, cannot, may, will, could, aarseth, chloroplasts,
# Nearest to seven: five, four, three, eight, six, nine, zero, two,
# Nearest to two: one, three, four, six, five, seven, eight, zero,
# Nearest to american: rupture, neuroscience, clan, ucd, cars, saltzer, reginae, alliterative,
# Nearest to than: rationalization, midday, qantas, barbagia, data, korca, employs, flippers,
# Nearest to its: the, their, his, a, ensured, haight, peremptory, hypotheses,
# Nearest to which: that, this, saipan, also, it, who, there, liabilities,
# Nearest to four: five, three, seven, six, eight, zero, nine, two,
# Nearest to years: cashier, browns, bashing, backlit, cliath, derision, parr, seldom,
# Nearest to their: his, its, the, condensate, eschewing, all, hate, level,
# Nearest to history: jaynes, noether, gate, bowie, iqs, newer, raj, larger,
# Nearest to about: definiteness, molloy, mcclintock, freude, spacecraft, atheist, crop, alphanumeric,
# Average loss at step 12000: 3.582648
# Average loss at step 14000: 3.618367
# Average loss at step 16000: 3.583694
# Average loss at step 18000: 3.571723
# Average loss at step 20000: 3.546184
# Nearest to as: by, libro, allergies, patchy, find, panther, muds, oprah,
# Nearest to has: had, have, was, is, since, by, grady, bribed,
# Nearest to most: speculate, more, gogo, many, trapezohedron, shimizu, finds, hunchback,
# Nearest to his: their, her, its, the, wieman, s, wires, trna,
# Nearest to can: may, would, will, cannot, must, could, might, should,
# Nearest to seven: eight, six, four, nine, five, three, zero, one,
# Nearest to two: four, three, six, five, seven, eight, one, nine,
# Nearest to american: uncover, british, anonymous, reginae, andersonville, clan, alliterative, imperial,
# Nearest to than: midday, but, qantas, severe, flippers, employs, much, burnt,
# Nearest to its: their, his, the, her, ensured, precarious, this, ventures,
# Nearest to which: that, this, also, these, it, both, classes, who,
# Nearest to four: six, seven, five, eight, three, nine, two, zero,
# Nearest to years: cashier, days, backlit, browns, renminbi, bashing, times, royalties,
# Nearest to their: his, its, the, her, some, precarious, all, each,
# Nearest to history: jaynes, madrigal, raj, iqs, noether, gate, rigorous, larger,
# Nearest to about: molloy, freude, sanj, accelerated, spacecraft, irritable, blass, definiteness,
# Average loss at step 22000: 3.530043
# Average loss at step 24000: 3.441207
# Average loss at step 26000: 3.418097
# Average loss at step 28000: 3.470747
# Average loss at step 30000: 3.411095
# Nearest to as: excerpts, allergies, from, patchy, for, tillman, algonquian, is,
# Nearest to has: had, have, is, was, bribed, mobile, tripod, showed,
# Nearest to most: more, speculate, many, gogo, some, use, less, hunchback,
# Nearest to his: their, her, its, the, s, wieman, callaghan, feed,
# Nearest to can: may, will, would, must, could, cannot, should, might,
# Nearest to seven: five, eight, six, nine, four, three, zero, two,
# Nearest to two: four, three, six, five, seven, eight, zero, nine,
# Nearest to american: british, adolph, inalienable, english, german, andersonville, d, contractual,
# Nearest to than: or, much, midday, flippers, allegiances, qantas, severe, quaternion,
# Nearest to its: their, his, the, her, any, precarious, this, ensured,
# Nearest to which: that, this, also, both, it, who, there, often,
# Nearest to four: six, five, three, seven, eight, two, nine, zero,
# Nearest to years: days, cashier, year, times, decades, broadcaster, browns, minutes,
# Nearest to their: its, his, her, the, precarious, some, any, listings,
# Nearest to history: jaynes, raj, disc, uninhabitable, battle, madrigal, burnside, iqs,
# Nearest to about: irritable, molloy, freude, over, sanj, woolly, rowan, accelerated,
# Average loss at step 32000: 3.421285
# Average loss at step 34000: 3.437166
# Average loss at step 36000: 3.367017
# Average loss at step 38000: 3.492354
# Average loss at step 40000: 3.447204
# Nearest to as: giuliano, when, cartography, is, ranches, rover, ratification, bombay,
# Nearest to has: had, have, was, is, since, showed, tripod, algardi,
# Nearest to most: more, many, speculate, less, gogo, lightness, holdings, cinematographers,
# Nearest to his: their, her, its, wieman, my, the, s, our,
# Nearest to can: may, will, could, cannot, must, would, should, might,
# Nearest to seven: eight, nine, six, five, four, zero, two, three,
# Nearest to two: three, five, six, four, seven, eight, zero, one,
# Nearest to american: british, italian, international, perkin, australian, inalienable, saltzer, bri,
# Nearest to than: much, or, midday, quaternion, flippers, mbe, backbench, glaciation,
# Nearest to its: their, his, the, her, your, precarious, some, my,
# Nearest to which: that, this, also, it, but, there, alphabetically, what,
# Nearest to four: five, six, eight, seven, three, zero, nine, two,
# Nearest to years: days, year, minutes, times, decades, months, cashier, broadcaster,
# Nearest to their: its, his, her, the, our, precarious, some, my,
# Nearest to history: jaynes, development, battle, raj, evolution, uninhabitable, formalization, rigorous,
# Nearest to about: sanj, irritable, blass, molloy, rowan, freude, raison, woolly,
# Average loss at step 42000: 3.422606
# Average loss at step 44000: 3.277583
# Average loss at step 46000: 3.410150
# Average loss at step 48000: 3.432887
# Average loss at step 50000: 3.436510
# Nearest to as: kanaris, halliday, ranches, became, coru, parastatal, implements, excerpts,
# Nearest to has: had, have, was, is, having, since, does, verbose,
# Nearest to most: more, many, speculate, some, gogo, less, use, horrific,
# Nearest to his: her, their, its, my, our, the, wieman, your,
# Nearest to can: may, will, would, could, must, cannot, might, should,
# Nearest to seven: eight, five, six, four, nine, three, zero, two,
# Nearest to two: three, four, seven, five, six, eight, one, nine,
# Nearest to american: british, italian, international, australian, inalienable, perkin, bri, uncover,
# Nearest to than: or, much, backbench, flippers, slightly, quaternion, mbe, undoing,
# Nearest to its: their, his, the, your, her, some, princeto, lough,
# Nearest to which: that, this, also, what, there, actually, generally, who,
# Nearest to four: five, six, seven, three, eight, nine, two, zero,
# Nearest to years: days, minutes, decades, times, year, months, degrees, people,
# Nearest to their: its, his, her, the, our, some, your, precarious,
# Nearest to history: raj, jaynes, development, uninhabitable, saline, prompted, burnside, onshore,
# Nearest to about: irritable, blass, sanj, urbanisation, molloy, satisfies, rowan, only,
# Average loss at step 52000: 3.452517
# Average loss at step 54000: 3.431108
# Average loss at step 56000: 3.405572
# Average loss at step 58000: 3.283118
# Average loss at step 60000: 3.383351
# Nearest to as: kanaris, panther, implements, when, cartography, ratification, newsletter, became,
# Nearest to has: had, have, is, was, since, having, marian, includes,
# Nearest to most: more, some, many, less, speculate, gogo, cinematographers, holdings,
# Nearest to his: her, their, its, the, your, our, my, wieman,
# Nearest to can: could, may, will, would, must, cannot, should, might,
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Nearest to two: three, four, five, seven, eight, six, one, nine,
# Nearest to american: italian, british, japanese, french, international, perkin, english, inalienable,
# Nearest to than: or, much, quaternion, slightly, flippers, even, moog, detrimental,
# Nearest to its: their, the, his, her, precarious, your, some, peremptory,
# Nearest to which: that, this, also, who, these, it, there, what,
# Nearest to four: six, five, three, eight, seven, two, nine, zero,
# Nearest to years: days, decades, minutes, months, year, times, leisurely, degrees,
# Nearest to their: its, his, her, the, our, your, some, precarious,
# Nearest to history: saline, raj, list, anomalies, prescription, development, delson, blockade,
# Nearest to about: irritable, blass, over, sanj, urbanisation, rowan, molloy, cascades,
# Average loss at step 62000: 3.438994
# Average loss at step 64000: 3.363523
# Average loss at step 66000: 3.339781
# Average loss at step 68000: 3.386302
# Average loss at step 70000: 3.372158
# Nearest to as: implements, shiraz, although, doi, became, amati, depict, where,
# Nearest to has: had, have, was, is, since, having, freeza, does,
# Nearest to most: more, many, some, less, speculate, cinematographers, among, holdings,
# Nearest to his: her, their, its, my, the, our, your, s,
# Nearest to can: will, would, could, may, must, should, cannot, might,
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Nearest to two: three, five, eight, four, six, seven, nine, one,
# Nearest to american: italian, british, including, french, international, australian, bri, japanese,
# Nearest to than: or, much, mbe, quaternion, but, slightly, flippers, zamboanga,
# Nearest to its: their, his, the, her, your, several, precarious, enriched,
# Nearest to which: this, that, also, what, who, however, there, itself,
# Nearest to four: five, six, three, eight, seven, nine, zero, two,
# Nearest to years: days, decades, minutes, year, months, times, hours, leisurely,
# Nearest to their: its, his, her, the, our, your, some, webmaster,
# Nearest to history: list, reaffirm, consists, twentieth, raj, development, saline, geography,
# Nearest to about: irritable, sanj, rowan, blass, over, molloy, freude, urbanisation,
# Average loss at step 72000: 3.404622
# Average loss at step 74000: 3.384700
# Average loss at step 76000: 3.351331
# Average loss at step 78000: 3.238976
# Average loss at step 80000: 3.372906
# Nearest to as: because, parastatal, when, implements, byrds, yamato, ahenobarbus, although,
# Nearest to has: had, have, is, was, since, includes, freeza, does,
# Nearest to most: more, many, some, all, less, cinematographers, various, gogo,
# Nearest to his: her, their, its, my, your, our, the, wieman,
# Nearest to can: will, may, could, would, must, should, cannot, might,
# Nearest to seven: six, eight, five, nine, four, three, zero, one,
# Nearest to two: three, one, six, five, four, eight, seven, zero,
# Nearest to american: british, italian, international, english, japanese, french, bri, inalienable,
# Nearest to than: or, much, quaternion, and, but, amazigh, mbe, slightly,
# Nearest to its: their, his, the, her, your, precarious, princeto, our,
# Nearest to which: this, that, also, usually, often, what, actually, typically,
# Nearest to four: five, six, seven, three, eight, zero, nine, two,
# Nearest to years: days, decades, minutes, year, months, times, hours, degrees,
# Nearest to their: its, his, her, our, your, the, my, precarious,
# Nearest to history: list, consists, modern, geography, saline, reaffirm, raj, development,
# Nearest to about: over, rowan, irritable, blass, molloy, genesis, sanj, complaints,
# Average loss at step 82000: 3.295514
# Average loss at step 84000: 3.337081
# Average loss at step 86000: 3.348344
# Average loss at step 88000: 3.325508
# Average loss at step 90000: 3.236849
# Nearest to as: became, nance, panther, tillman, halliday, yamato, for, fluctuation,
# Nearest to has: had, have, was, is, having, since, grady, algardi,
# Nearest to most: more, many, some, all, less, horrific, use, pdpa,
# Nearest to his: her, their, its, my, your, our, the, s,
# Nearest to can: could, will, would, must, cannot, may, should, might,
# Nearest to seven: five, six, eight, four, nine, three, zero, two,
# Nearest to two: three, four, five, seven, six, one, eight, zero,
# Nearest to american: british, italian, english, inalienable, bri, japanese, canadian, german,
# Nearest to than: much, or, quaternion, grasping, slightly, mineralogist, undoing, nine,
# Nearest to its: their, his, her, your, precarious, the, our, indictment,
# Nearest to which: that, this, also, actually, who, typically, usually, often,
# Nearest to four: six, seven, five, eight, three, nine, zero, two,
# Nearest to years: days, decades, minutes, year, months, times, hours, weeks,
# Nearest to their: its, his, her, our, your, my, some, rationalists,
# Nearest to history: list, raj, saline, geography, consists, modern, development, baz,
# Nearest to about: irritable, genesis, rowan, molloy, over, sanj, blass, freude,
# Average loss at step 92000: 2.732370
# Average loss at step 94000: 3.098701
# Average loss at step 96000: 3.064117
# Average loss at step 98000: 3.215399
# Average loss at step 100000: 3.276929
# Nearest to as: halliday, voluminous, attractor, boulez, transcontinental, doi, fluctuation, kanaris,
# Nearest to has: had, have, was, is, does, having, since, although,
# Nearest to most: more, less, some, many, particularly, especially, gogo, pdpa,
# Nearest to his: her, their, its, my, your, our, wieman, the,
# Nearest to can: could, will, would, must, cannot, may, should, might,
# Nearest to seven: six, eight, nine, five, four, three, zero, two,
# Nearest to two: three, four, five, six, seven, one, eight, zero,
# Nearest to american: british, english, japanese, irish, italian, indian, canadian, french,
# Nearest to than: or, much, quaternion, undoing, grasping, but, backbench, mineralogist,
# Nearest to its: their, his, her, the, our, your, whose, several,
# Nearest to which: that, this, also, actually, typically, these, who, both,
# Nearest to four: six, five, seven, three, eight, nine, two, zero,
# Nearest to years: days, decades, minutes, months, year, times, weeks, hours,
# Nearest to their: its, his, her, our, your, the, any, rationalists,
# Nearest to history: list, raj, baz, philosophy, origins, biography, saline, modern,
# Nearest to about: over, irritable, urbanisation, freude, molloy, genesis, sanj, mentality,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])
