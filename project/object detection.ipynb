# %% [markdown]
# 1. Numbers script sliding window to capture image size
# 2. predict on that

# %%
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os

# %%
model = load_model('D:/deepL_google/project/my_model.h5')

# %%
from keras.preprocessing import image

# %%
img_path = 'D:/deepL_google/project/numbres data/sub4.png'
img = image.load_img(img_path, target_size=(28, 28))
img_data = image.img_to_array(img)
img_data = img_data/255.0

# %%
print(img_data.shape)
type(img_data)
# Out:
# (28, 28, 3)
# numpy.ndarray

# %%
# img_data = img_data.reshape(1,1, 28, 28).astype('float32')

# %%
plt.imshow(img_data)
plt.show()
print('Image shape:',img_data.shape)
# Out:
# Image shape: (28, 28, 3)

# %%
import matplotlib.pyplot as plt


fig = plt.figure()
a=fig.add_subplot(1,2,1)
imgplot = plt.imshow(img_data[0:28,0:14,:])
# a.set_title('Before')

a=fig.add_subplot(1,2,2)
imgplot = plt.imshow(img_data[0:28,15:28,:])
# imgplot.set_clim(0.0,0.7)
# a.set_title('After')

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np

im = img_data

# Create figure and axes
fig,ax = plt.subplots(1)

# Display the image
ax.imshow(im)

# Create a Rectangle patch
rect = patches.Rectangle((0,0),#(x,y)
                         14, #width
                         26, #height
                         linewidth=1,edgecolor='r',facecolor='none')

# Add the patch to the Axes
ax.add_patch(rect)

# Create a Rectangle patch
rect = patches.Rectangle((15,0),#(x,y)
                         28, #width
                         26, #height
                         linewidth=1,edgecolor='r',facecolor='none')

# Add the patch to the Axes
ax.add_patch(rect)

plt.show()

# %% [markdown]
# ### Get Prediction

# %%
def reshape_img(img):
    return(img.reshape(1,1, 28, 28).astype('float32'))
    
# n1 = reshape_img(img_data[0:28,0:14,:])
# print(n1.shape)

n1 = img_data[0:28,0:14,1]
print(n1.shape)

# n1 = reshape_img(n1)
n1.resize(28,28)
# Out:
# (28, 14)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-fbb69b5cfa53> in <module>()
#       9
#      10 # n1 = reshape_img(n1)
# ---> 11 n1.resize(28,28)
#
# ValueError: resize only works on single-segment arrays

# %% [markdown]
# ### Sliding Window

# %%
import cv2

# %%
crop_img = img_data[200:400, 100:300] # Crop from x, y, w, h -> 100, 200, 300, 400
# NOTE: its img[y: y + h, x: x + w] and *not* img[x: x + w, y: y + h]
# cv2.imshow("cropped", img_data)
# cv2.waitKey(0)

# %%
# cv2.waitKey(0)
