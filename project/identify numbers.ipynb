# %%
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
model = load_model('D:/deepL_google/project/my_model.h5')

# %%
import pandas as pd
import numpy as np

# %%
# df_test.ix[1,:]

# %%
df_test = pd.read_csv('D:/deepL_google/project/test.csv')

# %%
x_test = np.array(df_test)

# %%
X_test = x_test.reshape(x_test.shape[0], 1, 28, 28).astype('float32')
X_test = X_test / 255

# %%
import matplotlib.pyplot as plt

# %%
def plt_img(idx):
    plt.imshow(X_test[idx,0])
    plt.show()

# %%
def get_prediction(idx):
    return(model.predict_classes(X_test[idx:idx+1,:,:,:]))

# %%
idx = 150
plt_img(idx)
get_prediction(idx)
# Out:
# 1/1 [==============================] - 0s
# array([4], dtype=int64)

# %% [markdown]
# ### Read image number and get prediction

# %%
import scipy
import scipy.ndimage

# %%
img_data = scipy.ndimage.imread('D:/deepL_google/project/numbres data/0.png')

# %%
print(img_data.shape)
type(img_data)
# Out:
# (193, 103, 4)
# numpy.ndarray

# %%
# img_data.reshape(1, 1, 28, 28).astype('float32')

# %%
from keras.preprocessing import image

# %%
img_path = 'D:/deepL_google/project/numbres data/9_0.png'
img = image.load_img(img_path, target_size=(28, 28))
img_data = image.img_to_array(img)
img_data = img_data/255.0

# %%
print(img_data.shape)
type(img_data)
# Out:
# (28, 28, 3)
# numpy.ndarray

# %%
x = img_data[:,:,1]

# %%
plt.imshow(x)
plt.show()
print('Image shape:',x.shape)
# Out:
# Image shape: (28, 28)

# %%
x= x.reshape(1,1, 28, 28).astype('float32')
print('Image shape:',x.shape)
# Out:
# Image shape: (1, 1, 28, 28)

# %%
plt.imshow(x[0,0])
plt.show()

# %%
model.predict_classes(x)
# Out:
# 1/1 [==============================] - 0s
# array([8], dtype=int64)
